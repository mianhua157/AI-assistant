# %%
# 代码块 1：基础测试（使用 OpenAI 兼容接口 - 推荐）
from openai import OpenAI

# 配置
API_KEY = "sk-b0f15faccf3f46cdb915d8d472e405a5"  # 从"API-KEY 管理"页面获取
BASE_URL = "https://dashscope.aliyuncs.com/compatible-mode/v1"
MODEL = "qwen3.5-plus"

# 创建客户端
client = OpenAI(
    api_key=API_KEY,
    base_url=BASE_URL
)

# 发起请求
response = client.chat.completions.create(
    model=MODEL,
    messages=[
        {"role": "user", "content": "请简单回复'连通性测试成功'"}
    ]
)

# 输出结果
print("✅ 基础 SDK 测试成功！")
print("模型回复:", response.choices[0].message.content)
# Out:
# ✅ 基础 SDK 测试成功！
# 模型回复: 连通性测试成功
